# %% [raw]
# ---
# title: "Practice Activity 6.1"
# author: "Antonio Gutierrez"
# output: html
# self-contained: true
# toc: true
# theme: cosmo
# echo: true
# ---

# %% [markdown]
# # Palmer Penguins Modeling
#
# Import the Palmer Penguins dataset and print out the first few rows.
#
# Suppose we want to predict `bill_depth_mm` using the other variables in the dataset.
#
# **Dummify** all variables that require this.

# %%
# !pip install palmerpenguins
from palmerpenguins import load_penguins

# %%
import pandas as pd
import numpy as np
from plotnine import *
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
penguins = load_penguins()
penguins = penguins.dropna()
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
lr = LinearRegression()
enc = OneHotEncoder()

ct = ColumnTransformer(
    [('dummify_s', enc, ['species']),
    ('dummify_i', enc, ['island']),
    ('dummify_sex', enc, ['sex'])],
)

# %%
my_pipeline = Pipeline(
    [('dummify',ct), ('ols',lr)]
)

# %%
X = penguins.drop('bill_depth_mm', axis = 1)
y = penguins['bill_depth_mm']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train
# Out:
#        species     island  bill_length_mm  flipper_length_mm  body_mass_g  \
# 43      Adelie      Dream            44.1              196.0       4400.0
# 314  Chinstrap      Dream            46.9              192.0       2700.0
# 306  Chinstrap      Dream            40.9              187.0       3200.0
# 164     Gentoo     Biscoe            45.5              214.0       4650.0
# 135     Adelie      Dream            41.1              190.0       3900.0
# ..         ...        ...             ...                ...          ...
# 120     Adelie  Torgersen            36.2              187.0       3150.0
# 93      Adelie      Dream            39.6              186.0       4450.0
# 233     Gentoo     Biscoe            52.5              221.0       5450.0
# 77      Adelie  Torgersen            37.2              184.0       3900.0
# 227     Gentoo     Biscoe            48.6              230.0       5800.0
#
#         sex  year
# 43     male  2007
# 314  female  2008
# 306  female  2008
# ...

# %%
fitted_pipeline = my_pipeline.fit(X_train, y_train)

fitted_pipeline
# Out:
# Pipeline(steps=[('dummify',
#                  ColumnTransformer(transformers=[('dummify_s', OneHotEncoder(),
#                                                   ['species']),
#                                                  ('dummify_i', OneHotEncoder(),
#                                                   ['island']),
#                                                  ('dummify_sex',
#                                                   OneHotEncoder(), ['sex'])])),
#                 ('ols', LinearRegression())])

# %%
ypreds = fitted_pipeline.predict(X_test)
ypreds
# Out:
# array([14.21875 , 17.625   , 14.21875 , 15.640625, 19.046875, 18.984375,
#        17.5625  , 19.      , 19.046875, 15.640625, 15.640625, 17.71875 ,
#        19.140625, 15.640625, 15.640625, 17.578125, 15.640625, 19.046875,
#        19.140625, 14.21875 , 17.71875 , 18.984375, 19.046875, 15.640625,
#        18.984375, 14.21875 , 17.625   , 14.21875 , 14.21875 , 17.578125,
#        14.21875 , 18.984375, 14.21875 , 19.      , 17.625   , 19.046875,
#        15.640625, 17.5625  , 19.      , 19.      , 17.625   , 14.21875 ,
#        14.21875 , 14.21875 , 14.21875 , 17.71875 , 17.625   , 17.625   ,
#        19.046875, 15.640625, 19.046875, 14.21875 , 19.      , 15.640625,
#        17.71875 , 17.578125, 15.640625, 19.      , 19.      , 15.640625,
#        19.      , 19.140625, 19.046875, 19.046875, 15.640625, 17.625   ,
#        18.984375, 14.21875 , 14.21875 , 17.5625  , 14.21875 , 14.21875 ,
#        17.5625  , 15.640625, 15.640625, 17.5625  , 14.21875 , 18.984375,
# ...

# %%
r2_score(ypreds, y_test) # test predicted values compared to the actual values
# Out:
# 0.8022392906301135

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Let's use the other variables to predict `bill_depth_mm`. Prepare your data and fit the following models on the entire dataset:
#
# * Four different models, each containing a different set of predictor variables
#
# Create a plot like the right plot of Fig 1. in our `Model Validation` chapter with the training and test error plotted for each of your four models.
#
# Which of your models was best?

# %% [markdown]
# ## Model 2

# %%
X = penguins.drop(penguins.columns[[3, 4]], axis=1)
y = penguins['bill_depth_mm']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train
# Out:
#        species     island  bill_length_mm  body_mass_g     sex  year
# 83      Adelie  Torgersen            35.1       4200.0    male  2008
# 38      Adelie      Dream            37.6       3300.0  female  2007
# 63      Adelie     Biscoe            41.1       4050.0    male  2008
# 297  Chinstrap      Dream            48.5       3400.0    male  2007
# 97      Adelie      Dream            40.3       4350.0    male  2008
# ..         ...        ...             ...          ...     ...   ...
# 205     Gentoo     Biscoe            50.1       5000.0    male  2008
# 72      Adelie  Torgersen            39.6       3550.0  female  2008
# 234     Gentoo     Biscoe            47.4       4725.0  female  2009
# 335  Chinstrap      Dream            45.6       3525.0  female  2009
# 98      Adelie      Dream            33.1       2900.0  female  2008
#
# [249 rows x 6 columns]

# %%
fitted_pipeline = my_pipeline.fit(X_train, y_train)

# %%
ypreds2 = fitted_pipeline.predict(X_test)
ypreds2
# Out:
# array([19.03125, 17.625  , 14.25   , 15.8125 , 17.625  , 19.25   ,
#        15.8125 , 15.8125 , 17.59375, 17.59375, 17.6875 , 14.25   ,
#        14.25   , 17.6875 , 15.8125 , 14.25   , 14.25   , 14.25   ,
#        19.25   , 15.8125 , 15.8125 , 19.15625, 14.25   , 17.6875 ,
#        19.15625, 14.25   , 19.03125, 17.46875, 17.59375, 19.03125,
#        15.8125 , 19.03125, 14.25   , 17.6875 , 19.25   , 14.25   ,
#        17.59375, 19.25   , 19.1875 , 17.6875 , 15.8125 , 19.25   ,
#        17.625  , 14.25   , 19.1875 , 19.25   , 17.59375, 14.25   ,
#        19.25   , 19.25   , 14.25   , 19.1875 , 19.1875 , 17.59375,
#        17.6875 , 15.8125 , 14.25   , 17.46875, 15.8125 , 15.8125 ,
#        17.46875, 14.25   , 19.1875 , 19.15625, 19.15625, 17.46875,
#        14.25   , 19.25   , 17.46875, 19.25   , 19.25   , 17.46875,
#        14.25   , 17.46875, 15.8125 , 17.59375, 19.03125, 19.1875 ,
#        15.8125 , 17.6875 , 17.59375, 14.25   , 19.15625, 15.8125 ])

# %%
r2_score(ypreds2, y_test)
# Out:
# 0.8337394216717228

# %% [markdown]
# ## Model 3

# %%
X = penguins.drop(penguins.columns[[3, 5]], axis=1)
y = penguins['bill_depth_mm']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train
# Out:
#        species     island  bill_length_mm  flipper_length_mm     sex  year
# 131     Adelie  Torgersen            43.1              197.0    male  2009
# 284  Chinstrap      Dream            46.0              195.0  female  2007
# 196     Gentoo     Biscoe            50.5              222.0    male  2008
# 62      Adelie     Biscoe            37.6              185.0  female  2008
# 316  Chinstrap      Dream            49.0              210.0    male  2008
# ..         ...        ...             ...                ...     ...   ...
# 95      Adelie      Dream            40.8              208.0    male  2008
# 129     Adelie  Torgersen            44.1              210.0    male  2009
# 176     Gentoo     Biscoe            42.9              215.0  female  2007
# 78      Adelie  Torgersen            36.2              187.0  female  2008
# 73      Adelie  Torgersen            45.8              197.0    male  2008
#
# [249 rows x 6 columns]

# %%
fitted_pipeline = my_pipeline.fit(X_train, y_train)

# %%
ypreds3 = fitted_pipeline.predict(X_test)
ypreds3
# Out:
# array([15.78125, 17.59375, 17.59375, 19.15625, 17.59375, 15.78125,
#        15.78125, 15.78125, 17.59375, 19.15625, 15.78125, 14.21875,
#        17.4375 , 15.78125, 17.59375, 14.21875, 14.21875, 19.     ,
#        19.15625, 15.78125, 14.21875, 19.15625, 15.78125, 17.59375,
#        14.21875, 19.375  , 19.     , 17.59375, 19.15625, 14.21875,
#        17.59375, 14.21875, 17.59375, 19.15625, 14.21875, 14.21875,
#        14.21875, 17.59375, 19.15625, 14.21875, 17.4375 , 15.78125,
#        14.21875, 19.375  , 19.     , 19.15625, 14.21875, 15.78125,
#        15.78125, 19.15625, 17.59375, 17.59375, 19.     , 19.15625,
#        19.15625, 19.15625, 19.375  , 19.15625, 17.4375 , 15.78125,
#        17.59375, 15.78125, 17.59375, 19.15625, 15.78125, 17.4375 ,
#        17.4375 , 19.     , 17.59375, 19.15625, 19.15625, 19.15625,
#        19.     , 14.21875, 17.59375, 17.59375, 17.8125 , 15.78125,
#        19.15625, 19.15625, 19.375  , 15.78125, 17.59375, 15.78125])

# %%
r2_score(ypreds3, y_test)
# Out:
# 0.8082363299483779

# %% [markdown]
# ## Model 4

# %%
X = penguins.drop(penguins.columns[[3, 5, 7]], axis=1)
y = penguins['bill_depth_mm']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train
# Out:
#        species  island  bill_length_mm  flipper_length_mm     sex
# 211     Gentoo  Biscoe            50.4              224.0    male
# 267     Gentoo  Biscoe            55.1              230.0    male
# 269     Gentoo  Biscoe            48.8              222.0    male
# 92      Adelie   Dream            34.0              185.0  female
# 67      Adelie  Biscoe            41.1              188.0    male
# ..         ...     ...             ...                ...     ...
# 333  Chinstrap   Dream            49.3              203.0    male
# 61      Adelie  Biscoe            41.3              195.0    male
# 311  Chinstrap   Dream            47.5              199.0  female
# 141     Adelie   Dream            40.6              187.0    male
# 322  Chinstrap   Dream            50.1              190.0  female
#
# [249 rows x 5 columns]

# %%
fitted_pipeline = my_pipeline.fit(X_train, y_train)

# %%
ypreds4 = fitted_pipeline.predict(X_test)
ypreds4
# Out:
# array([19.14331055, 19.14331055, 17.65112305, 14.26049805, 15.74487305,
#        17.65893555, 19.14331055, 15.74487305, 19.14331055, 17.36987305,
#        17.65893555, 15.74487305, 15.74487305, 15.74487305, 19.10424805,
#        19.10424805, 14.26049805, 17.36987305, 15.74487305, 17.61987305,
#        17.65112305, 15.74487305, 19.13549805, 17.65893555, 15.74487305,
#        17.65112305, 14.26049805, 17.65112305, 17.36987305, 15.74487305,
#        14.26049805, 18.85424805, 17.65112305, 17.61987305, 19.10424805,
#        18.85424805, 17.36987305, 14.26049805, 19.13549805, 14.26049805,
#        15.74487305, 19.13549805, 17.61987305, 15.74487305, 15.74487305,
#        19.13549805, 14.26049805, 14.26049805, 15.74487305, 19.10424805,
#        14.26049805, 19.14331055, 14.26049805, 19.13549805, 17.65893555,
#        15.74487305, 18.85424805, 18.85424805, 19.13549805, 17.65112305,
#        17.61987305, 19.13549805, 15.74487305, 14.26049805, 19.14331055,
# ...

# %%
r2_score(ypreds4, y_test)
# Out:
# 0.7164171683855965

# %% [markdown]
# ## Plot

# %%
# RMSE for each set of predictions
rmse1 = mean_squared_error(y_test, ypreds, squared=False)
rmse2 = mean_squared_error(y_test, ypreds2, squared=False)
rmse3 = mean_squared_error(y_test, ypreds3, squared=False)
rmse4 = mean_squared_error(y_test, ypreds4, squared=False)


# Created a DataFrame for RMSE values
df_rmse = pd.DataFrame({
    'Model': ['Model 1', 'Model 2', 'Model 3', 'Model 4'],
    'RMSE': [rmse1, rmse2, rmse3, rmse4]
})

# Create a bar plot for RMSE values
rmse_plot = (
    ggplot(df_rmse, aes(x='Model', y='RMSE', fill='Model')) +
    geom_bar(stat='identity', position='dodge') +
    labs(x='Model', y='RMSE', title='Comparison of Model RMSE') +
    theme_light()
)

rmse_plot
# Out:
# <Figure Size: (640 x 480)>
