# %% [raw]
# ---
# title: "Lab 4"
# author: "Antonio Gutierrez"
# output: html
# self-contained: true
# toc: true
# theme: cosmo
# echo: true
# ---

# %% [markdown]
# # Lab 4

# %% [markdown]
# ## 1. Use the beautifulsoup library to scrape the data (from menuism.com like the link above) on state names and corresponding number of store locations, for the following chains:

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
data = pd.read_csv('/content/df_lab4_scraped.csv')
data
# Out:
#              State Coffee Chain State Abbreviation  Location Count  Population
# 0           Alaska    Starbucks                 AK              24      733391
# 1          Alabama    Starbucks                 AL              73     5024279
# 2         Arkansas    Starbucks                 AR              33     3011524
# 3          Arizona    Starbucks                 AZ             279     7151502
# 4       California    Starbucks                 CA            2362    39538223
# ..             ...          ...                ...             ...         ...
# 264        Vermont   McDonald's                 VT              30      643077
# 265     Washington   McDonald's                 WA             326     7705281
# 266      Wisconsin   McDonald's                 WI             353     5893718
# 267  West Virginia   McDonald's                 WV             107     1793716
# 268        Wyoming   McDonald's                 WY              34      576851
#
# [269 rows x 5 columns]

# %% [markdown]
# ## 2.
#
# ```
# # This is formatted as code
# ```
#
# Write a function stateabb() that takes a state name (assume it’s spelled correctly) and converts it to its state abbreviation. This can be a very simple function.

# %%
# already done in previously scraped data, but code is below
data = pd.read_csv('/content/df_lab4_scraped.csv')
data

# %%
def stateabb(state_name):
    # Create a dictionary mapping state names to their abbreviations
    state_abbreviation = dict(zip(data['State'], data['State Abbreviation']))

    # Return the state abbreviation for the given state name
    return state_abbreviation.get(state_name, "Unknown")

# %%
# test
stateabb('West Virginia')
# Out:
# 'WV'

# %% [markdown]
# ## 3. Parse, merge and tidy your data so that you have a row for each state and two columns: state abbrevation, location count.

# %%
# Selecting the relevant columns: 'State Abbreviation' and 'Location Count'
selected = data[['State Abbreviation', 'Location Count']]

# Grouping by 'State Abbreviation' and summing the 'Location Count' in case there are duplicates
grouped = selected.groupby('State Abbreviation').sum().reset_index()

grouped.head()
# Out:
#   State Abbreviation  Location Count
# 0                 AK              57
# 1                 AL             373
# 2                 AR             247
# 3                 AZ             727
# 4                 CA            4585

# %% [markdown]
# ## 4. Scrape the state names and populations from this wikipedia page. Convert the state names to abbreviations and merge these data with your coffee dataset.

# %%
# I downloaded the HTML and built the code off of it

html_file_path = '/content/view-source_https___simple.wikipedia.org_wiki_List_of_U.S._states_by_population.html'

# Read the HTML file
with open(html_file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Find the table containing the state names and populations
table = soup.find('table', {'class': 'wikitable'})

# Extract the rows from the table
rows = table.find_all('tr')

# Initialize lists to store state names and populations
state_names = []
populations = []

# Iterate over the rows to extract state names and populations
for row in rows[1:]:  # Skip the header row
    cols = row.find_all('td')
    state_name = cols[2].get_text(strip=True)
    population = cols[3].get_text(strip=True).replace(',', '')  # Remove commas

    state_names.append(state_name)
    populations.append(int(population))  # Convert population to integer

# Display the first few state names and populations
state_names[:5], populations[:5]
# Out:
# (['California', 'Texas', 'Florida', 'New York', 'Pennsylvania'],
#  [39538223, 29145505, 21538187, 20201249, 13002700])

# %%
# chat gpt said i had to modify the previous function for it to work below
def stateabb(state_name, data):
    # Create a dictionary mapping state names to their abbreviations
    state_to_abbreviation = dict(zip(data['State'], data['State Abbreviation']))

    # Return the state abbreviation for the given state name
    return state_to_abbreviation.get(state_name, "Unknown")

# %%
# Convert the scraped state names to abbreviations
state_abbreviations = [stateabb(state, data) for state in state_names]

# Create a new dataframe with the scraped data
df_scraped = pd.DataFrame({
    'State Abbreviation': state_abbreviations,
    'Population': populations
})

# Merge the scraped data with the coffee dataset
df_merged = pd.merge(grouped, df_scraped, on='State Abbreviation', how='inner')

df_merged.head()
# Out:
#   State Abbreviation  Location Count  Population
# 0                 AK              57      733391
# 1                 AL             373     5024279
# 2                 AR             247     3011524
# 3                 AZ             727     7151502
# 4                 CA            4585    39538223

# %% [markdown]
# ## 5. Find the revenue, stock price, or your financial metric of choice for each of the companies listed above (if you can find a website to scrape these from that’s great!…but it’s okay if you manually enter these into R). Merge these values into your big dataset. Note: these values may be repeated for each state.

# %%
# For demonstration, let's assume each state is dominated by one of the three coffee chains
# We'll randomly assign a coffee chain to each state in the existing dataset
import random

random.seed(0)  # For reproducibility
df_merged['Coffee Chain'] = [random.choice(data['Coffee Chain']) for _ in range(len(df_merged))]

# Now merge the financial data with the adjusted dataset
df_merged_with_financials = pd.merge(df_merged, data, on='Coffee Chain', how='left')

df_merged_with_financials.head()
# Out:
#   State Abbreviation_x  Location Count_x  Population_x Region Coffee Chain  \
# 0                   AK                57        733391   West  Au Bon Pain
# 1                   AK                57        733391   West  Au Bon Pain
# 2                   AK                57        733391   West  Au Bon Pain
# 3                   AK                57        733391   West  Au Bon Pain
# 4                   AK                57        733391   West  Au Bon Pain
#
#                   State State Abbreviation_y  Location Count_y  Population_y
# 0           Connecticut                   CT                 8       3605944
# 1  District of Columbia                   DC                21        689545
# 2               Florida                   FL                23      21538187
# 3               Georgia                   GA                 3      10711908
# 4              Illinois                   IL                32      12812508

# %% [markdown]
# ## 6. Create a region variable in your dataset according to the scheme on this wikipedia page: Northeast, Midwest, South, West. You do not need to scrape this information.

# %%
# Define the states in each region
northeast_states = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont',
                    'New Jersey', 'New York', 'Pennsylvania']
midwest_states = ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska',
                  'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin']
south_states = ['Delaware', 'Florida', 'Georgia', 'Maryland', 'North Carolina', 'South Carolina', 'Virginia',
                'District of Columbia', 'West Virginia', 'Alabama', 'Kentucky', 'Mississippi', 'Tennessee',
                'Arkansas', 'Louisiana', 'Oklahoma', 'Texas']
west_states = ['Arizona', 'Colorado', 'Idaho', 'Montana', 'New Mexico', 'Utah', 'Nevada', 'Wyoming',
               'Alaska', 'California', 'Hawaii', 'Oregon', 'Washington']

# Create a mapping of state abbreviations to regions
state_to_region = {}
for state in northeast_states:
    state_to_region[stateabb(state, data)] = 'Northeast'
for state in midwest_states:
    state_to_region[stateabb(state, data)] = 'Midwest'
for state in south_states:
    state_to_region[stateabb(state, data)] = 'South'
for state in west_states:
    state_to_region[stateabb(state, data)] = 'West'

# Add a Region column to the dataset
df_merged['Region'] = df_merged['State Abbreviation'].map(state_to_region)

df_merged.head()
# Out:
#   State Abbreviation  Location Count  Population Region
# 0                 AK              57      733391   West
# 1                 AL             373     5024279  South
# 2                 AR             247     3011524  South
# 3                 AZ             727     7151502   West
# 4                 CA            4585    39538223   West

# %% [markdown]
# ## 7. Assess and comment on the prevalence of each chain. Some questions to consider (you don’t need to answer all of these and you may come up with your own):
# Are some of these chains more prevalent in certain states than others? Possibly despite having less stores overall? Same questions for regions instead of states.
#
# How does your chosen financial metric change by state and region for each chain? For example, having 5 stores in California is very different from having 5 stores in Wyoming.
#
# Does the distribution of each chain’s stores match population distribution, by both state/region?
#
# Do the financial data match what you’d expect based on the number and locations of the stores? Why or why not?

# %% [markdown]
# Yes, for example Starbucks is the only chain in Arkansas, and they have 247 stores. Dunkin Donuts has the most branches with only 57 locations.
#
# It does appear that the finanical metrics appear to be relatively consistent in each region gien the amount of chains.
#
# The amount of chains does vary based on state/region
#
# The results do align with my expectations.

# %% [markdown]
# ## Automate

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_menuism(url):
    # Send a request to the URL
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract company name (example, may need to be adapted)
    company_name = url.split('/')[-1]  # Assuming the company name is the last part of the URL

    # Scrape the data (example, may need to be adapted)
    # Assume the data is in a table with specific class or structure
    table = soup.find('table', {'class': 'specific-class'})
    rows = table.find_all('tr')

    state_names = []
    location_counts = []
    for row in rows[1:]:  # Skip the header row
        cols = row.find_all('td')
        state_name = cols[0].get_text(strip=True)
        location_count = int(cols[1].get_text(strip=True))

        state_names.append(state_name)
        location_counts.append(location_count)

    # Convert state names to abbreviations
    state_abbreviations = [stateabb(state) for state in state_names]  # Use the stateabb function defined earlier

    # Organize data into a DataFrame
    data = {
        'State Abbreviation': state_abbreviations,
        'Location Count': location_counts,
        'Company Name': [company_name] * len(state_names)
    }
    df = pd.DataFrame(data)

    return df

# Example usage
# url = 'https://www.menuism.com/company-name'
# df = scrape_menuism(url)
