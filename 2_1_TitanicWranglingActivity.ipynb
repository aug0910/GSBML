# %% [raw]
# ---
# title: "2.1 Titanic Wrangling Activity"
# author: "Antonio Gutierrez"
# output: html
# self-contained: true
# toc: true
# theme: cosmo
# echo: true
# ---

# %% [markdown]
# # Titanic Wrangling
#
# In this practice activity you'll continue to work with the titanic dataset in ways that flex what you've learned about both data wrangling and data visualization.

# %%
import numpy as np
import pandas as pd

# %%
data_dir = "https://dlsun.github.io/pods/data/"
df_titanic = pd.read_csv(data_dir + "titanic.csv")

# %% [markdown]
# ## 1. Filter the data to include passengers only. Calculate the joint distribution (cross-tab) between a passenger's class and where they embarked.

# %%
df_titanic["type"] = df_titanic["class"].map({
    "1st": "passenger",
    "2nd": "passenger",
    "3rd": "passenger",
    "victualling crew": "crew",
    "engineering crew": "crew",
    "deck crew": "crew"
})

df_titanic
# Out:
#                                 name  gender   age             class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0               3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0               3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0               3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0               3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0               3rd        S
# ...                              ...     ...   ...               ...      ...
# 2202                Wynn, Mr. Walter    male  41.0         deck crew        B
# 2203             Yearsley, Mr. Harry    male  40.0  victualling crew        S
# 2204        Young, Mr. Francis James    male  32.0  engineering crew        S
# 2205             Zanetti, Sig. Minio    male  20.0  restaurant staff        S
# 2206              Zarracchi, Sig. L.    male  26.0  restaurant staff        S
#
# ...

# %%
# Filter to only passengers
df_titanic = df_titanic[df_titanic["type"] == "passenger"]
df_titanic
# Out:
#                                 name  gender   age class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0   3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0   3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0   3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0   3rd        S
# ...                              ...     ...   ...   ...      ...
# 1314          Yvois, Miss. Henriette  female  24.0   2nd        S
# 1315       Zakarian, Mr. Mapriededer    male  22.0   3rd        C
# 1316             Zakarian, Mr. Ortin    male  27.0   3rd        C
# 1317               Zenni, Mr. Philip    male  25.0   3rd        C
# 1318             Zimmermann, Mr. Leo    male  29.0   3rd        S
#
#             country  ticketno     fare  survived       type
# 0     United States    5547.0   7.1100         0  passenger
# ...

# %%
# Raw Numbers Version
pd.crosstab(df_titanic['class'], df_titanic['embarked'], margins=True, margins_name="Total")
# Out:
# embarked  B    C    Q    S  Total
# class
# 1st       3  143    3  175    324
# 2nd       6   26    7  245    284
# 3rd       0  102  113  494    709
# Total     9  271  123  914   1317

# %%
# Proportion Version
pd.crosstab(df_titanic['class'], df_titanic['embarked'], margins=True, margins_name="Total", normalize = True) # Chat GPT assisted with Total column and row.
# Out:
# embarked         B         C         Q         S     Total
# class
# 1st       0.002278  0.108580  0.002278  0.132878  0.246014
# 2nd       0.004556  0.019742  0.005315  0.186029  0.215642
# 3rd       0.000000  0.077449  0.085801  0.375095  0.538345
# Total     0.006834  0.205771  0.093394  0.694002  1.000000

# %% [markdown]
# ## 2. Using the joint distribution that calculated above, calculate the following:
#
# * the conditional distribution of their class given where they embarked
# * the conditional distribution of where they embarked given their class
#
# Use the conditional distributions that you calculate to answer the following quesitons:
#
# * What proportion of 3rd class passengers embarked at Southampton?
# * What proportion of Southampton passengers were in 3rd class?

# %% [markdown]
# The proportion of 3rd class passengers that embarked at Southampton is 0.540481

# %%
# The conditional distribution of their class given where they embarked.
pd.crosstab(df_titanic['class'], df_titanic['embarked'], normalize='columns')
# Out:
# embarked         B         C         Q         S
# class
# 1st       0.333333  0.527675  0.024390  0.191466
# 2nd       0.666667  0.095941  0.056911  0.268053
# 3rd       0.000000  0.376384  0.918699  0.540481

# %% [markdown]
# The proportion of Southampton passengers that were in 3rd class is 0.696756.

# %%
# The conditional distribution of where they embarked given their class.
pd.crosstab(df_titanic['class'], df_titanic['embarked'], normalize='index')
# Out:
# embarked         B         C         Q         S
# class
# 1st       0.009259  0.441358  0.009259  0.540123
# 2nd       0.021127  0.091549  0.024648  0.862676
# 3rd       0.000000  0.143865  0.159379  0.696756

# %% [markdown]
# ## 3. Make a visualization showing the distribution of a passenger's class, given where they embarked.
#
# Discuss the pros and cons of using this visualization versus the distributions you calculated before, to answer the previous questions.

# %%
data = df_titanic

# %%
from plotnine import *

# %%
plot = (
    ggplot(data, aes(x='class'))
    + geom_bar(aes(fill='class'))
    + labs(title='Distribution of Passenger Class, Given Where They Embarked', x='Passenger Class', y='Count')
    + theme_light()
    + facet_wrap('~embarked')
    + scale_fill_manual(
        breaks=('1st', '2nd', '3rd'),
        values=('crimson', 'green', 'royalblue'))
)

plot
# Out:
# <Figure Size: (640 x 480)>
